# %%
import pandas as pd

sales = pd.read_csv(r"C:\Users\Kevin\Desktop\transactions.csv")
# 1. Muudame kuupäeva õigesse vormingusse
sales["date"] = pd.to_datetime(sales["date"])

# 2. Paneme kuupäeva indekseerima (nüüd see asendab need numbrid 0, 1, 2...)
sales_multi = sales.set_index(["date", "store_nbr"])

sales_multi.loc[("2013-11-11", 11):("2013-11-12", 13)]
sales_multi.loc[(["2013-11-11", "2013-11-12"], [11, 13]), :]

new = sales.groupby(["date", "store_nbr"]).agg({"transactions": ["sum", "mean"]})
new.loc["2013-02-10"]

new1 = new.droplevel(0, axis=1)
new1.swaplevel().loc[15]
new1.reset_index()
# Out:
#             date  store_nbr   sum    mean
# 0     2013-01-01         25   770   770.0
# 1     2013-01-02          1  2111  2111.0
# 2     2013-01-02          2  2358  2358.0
# 3     2013-01-02          3  3487  3487.0
# 4     2013-01-02          4  1922  1922.0
# ...          ...        ...   ...     ...
# 83483 2017-08-15         50  2804  2804.0
# 83484 2017-08-15         51  1573  1573.0
# 83485 2017-08-15         52  2255  2255.0
# 83486 2017-08-15         53   932   932.0
# 83487 2017-08-15         54   802   802.0
#
# [83488 rows x 4 columns]
