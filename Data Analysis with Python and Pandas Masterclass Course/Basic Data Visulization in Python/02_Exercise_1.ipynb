# %%
import pandas as pd

oil = pd.read_csv(r"C:\Users\Kevin\Desktop\oil.csv")
oil.columns = ["dates", "prices"]

# %%
oil.head()
# Out:
#         dates  prices
# 0  2013-01-01     NaN
# 1  2013-01-02   93.14
# 2  2013-01-03   92.97
# 3  2013-01-04   93.12
# 4  2013-01-07   93.20

# %%
oil.tail()
# Out:
#            dates  prices
# 1213  2017-08-25   47.65
# 1214  2017-08-28   46.40
# 1215  2017-08-29   46.46
# 1216  2017-08-30   45.96
# 1217  2017-08-31   47.26

# %%
new = (oil.set_index("dates")["prices"]).plot()

new
# Out:
# <Axes: xlabel='dates'>
